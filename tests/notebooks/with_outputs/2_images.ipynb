# %% [markdown]
# # A matplotlib plot

# %%
import matplotlib.pyplot as plt

plt.bar([0,1,2], [1,3,2])
plt.show()

# %% [markdown]
# # Using Image

# %% [markdown]
# First we use image on a link

# %%
from IPython.core.display import Image
Image("https://raw.githubusercontent.com/mwouts/jupytext/master/docs/jupytext_word_cloud.png")

# %% [markdown]
# And then we include a local file:

# %%
Image('../../../docs/jupytext_word_cloud.png')
